# %%
# !pip install nltk
# !pip install scikit-learn
# !pip install flask
# !pip install pandas
# !pip install numpy
# Out:
# Requirement already satisfied: nltk in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.9.4)
# Requirement already satisfied: click in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (8.4.1)
# Requirement already satisfied: joblib in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from nltk) (4.68.1)
# Requirement already satisfied: colorama in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: scikit-learn in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (2.4.6)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: flask in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.1.3)
# Requirement already satisfied: blinker>=1.9.0 in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from flask) (8.4.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from flask) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from flask) (3.1.8)
# Requirement already satisfied: colorama in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: pandas in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: numpy in C:\Users\Fayaz\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.4.6)

# %%
import nltk

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Fayaz\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Fayaz\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Fayaz\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# %run train.py
# Out:
# Training Completed

# %%
from chatbot import get_response

while True:

    msg = input("You: ")

    if msg.lower() == "quit":
        break

    print(
        "Bot:",
        get_response(msg)
    )
# Out:
# You:  hello
# Bot: Hello!
# You:  thanks
# Bot: You're Welcome
# You:  quit

# %%
from sklearn.metrics import accuracy_score

predictions = model.predict(X)

accuracy = accuracy_score(
    tags,
    predictions
)

print(
    "Accuracy:",
    accuracy
)
# Out:
# Accuracy: 1.0
